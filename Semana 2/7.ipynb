# %% [markdown]
# Missing Values

# %% [markdown]
# Muchas veces tenemos valores que faltan dentro de un conjunto de datos, que puede tener justificacion de algun tipo y es necesario saber
# como debemos manejar dichos valores

# %%
import pandas as pd

df = pd.read_csv('class_grades.csv')
df.head(10)
# Out:
#    Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0       5       57.14     34.09    64.38     51.48  52.50
# 1       8       95.05    105.49    67.50     99.07  68.33
# 2       8       83.70     83.17      NaN     63.15  48.89
# 3       7         NaN       NaN    49.38    105.93  80.56
# 4       8       91.32     93.64    95.00    107.41  73.89
# 5       7       95.00     92.58    93.12     97.78  68.06
# 6       8       95.05    102.99    56.25     99.07  50.00
# 7       7       72.85     86.85    60.00       NaN  56.11
# 8       8       84.26     93.10    47.50     18.52  50.83
# 9       7       90.10     97.55    51.25     88.89  63.61

# %%
#una manera de filtrar estos datos es medinte el uso de la funcion isnull y usar sus resultados como mascara para el dataframe
mask = df.isnull()
mask
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0    False       False     False    False     False  False
# 1    False       False     False    False     False  False
# 2    False       False     False     True     False  False
# 3    False        True      True    False     False  False
# 4    False       False     False    False     False  False
# ..     ...         ...       ...      ...       ...    ...
# 94   False        True     False    False     False  False
# 95   False        True     False    False     False  False
# 96   False       False     False    False     False  False
# 97   False       False     False    False     False  False
# 98   False       False     False    False     False  False
#
# [99 rows x 6 columns]

# %%
#otra funcionque nos puede ayudar a filtrar filas con datos faltantes viene a ser dropna
df.dropna().head(10)
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0        5       57.14     34.09    64.38     51.48  52.50
# 1        8       95.05    105.49    67.50     99.07  68.33
# 4        8       91.32     93.64    95.00    107.41  73.89
# 5        7       95.00     92.58    93.12     97.78  68.06
# 6        8       95.05    102.99    56.25     99.07  50.00
# 8        8       84.26     93.10    47.50     18.52  50.83
# 9        7       90.10     97.55    51.25     88.89  63.61
# 10       7       80.44     90.20    75.00     91.48  39.72
# 12       8       97.16    103.71    72.50     93.52  63.33
# 13       7       91.28     83.53    81.25     99.81  92.22

# %%
#y si lo que queremos es llenar los valores na con un valor determinado podemos usar fillna
df.fillna(0, inplace=True)
df.head(10)
# Out:
#    Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0       5       57.14     34.09    64.38     51.48  52.50
# 1       8       95.05    105.49    67.50     99.07  68.33
# 2       8       83.70     83.17     0.00     63.15  48.89
# 3       7        0.00      0.00    49.38    105.93  80.56
# 4       8       91.32     93.64    95.00    107.41  73.89
# 5       7       95.00     92.58    93.12     97.78  68.06
# 6       8       95.05    102.99    56.25     99.07  50.00
# 7       7       72.85     86.85    60.00      0.00  56.11
# 8       8       84.26     93.10    47.50     18.52  50.83
# 9       7       90.10     97.55    51.25     88.89  63.61

# %%
#tambien muchas veces los datos filtrados como NaN puedes tener valores utiles que pandas interpreta como vacios
#una forma de corregir esto es la siguiente manera
df = pd.read_csv('log.csv')
df.head(10)
# Out:
#          time    user       video  playback position paused  volume
# 0  1469974424  cheryl  intro.html                  5  False    10.0
# 1  1469974454  cheryl  intro.html                  6    NaN     NaN
# 2  1469974544  cheryl  intro.html                  9    NaN     NaN
# 3  1469974574  cheryl  intro.html                 10    NaN     NaN
# 4  1469977514     bob  intro.html                  1    NaN     NaN
# 5  1469977544     bob  intro.html                  1    NaN     NaN
# 6  1469977574     bob  intro.html                  1    NaN     NaN
# 7  1469977604     bob  intro.html                  1    NaN     NaN
# 8  1469974604  cheryl  intro.html                 11    NaN     NaN
# 9  1469974694  cheryl  intro.html                 14    NaN     NaN

# %%
df = df.set_index('time')
df = df.sort_index()
df.head(10)
# Out:
#               user          video  playback position paused  volume
# time
# 1469974424  cheryl     intro.html                  5  False    10.0
# 1469974424     sue  advanced.html                 23  False    10.0
# 1469974454  cheryl     intro.html                  6    NaN     NaN
# 1469974454     sue  advanced.html                 24    NaN     NaN
# 1469974484  cheryl     intro.html                  7    NaN     NaN
# 1469974514  cheryl     intro.html                  8    NaN     NaN
# 1469974524     sue  advanced.html                 25    NaN     NaN
# 1469974544  cheryl     intro.html                  9    NaN     NaN
# 1469974554     sue  advanced.html                 26    NaN     NaN
# 1469974574  cheryl     intro.html                 10    NaN     NaN

# %%
#como podemos observar hay usuarios que tienen el mismo indice entonces haremos un filtrado de indice multiple
df = df.reset_index()
df = df.set_index(['time', 'user'])
df.head(10)
# Out:
#                            video  playback position paused  volume
# time       user
# 1469974424 cheryl     intro.html                  5  False    10.0
#            sue     advanced.html                 23  False    10.0
# 1469974454 cheryl     intro.html                  6    NaN     NaN
#            sue     advanced.html                 24    NaN     NaN
# 1469974484 cheryl     intro.html                  7    NaN     NaN
# 1469974514 cheryl     intro.html                  8    NaN     NaN
# 1469974524 sue     advanced.html                 25    NaN     NaN
# 1469974544 cheryl     intro.html                  9    NaN     NaN
# 1469974554 sue     advanced.html                 26    NaN     NaN
# 1469974574 cheryl     intro.html                 10    NaN     NaN

# %%
#una vez ordenado nuestro dataframe de manera adecuada podemos usar el llenado de valores NaN
df = df.fillna(method='ffill')
df.head()
# Out:
#                            video  playback position  paused  volume
# time       user
# 1469974424 cheryl     intro.html                  5   False    10.0
#            sue     advanced.html                 23   False    10.0
# 1469974454 cheryl     intro.html                  6   False    10.0
#            sue     advanced.html                 24   False    10.0
# 1469974484 cheryl     intro.html                  7   False    10.0

# %%
#y vemos que hemos llenado los valores faltante con los valores anteriores a estos gracias a la metodo ffill
df = pd.DataFrame({'A' : [1,1,2,3,4],
                   'B' : [3,6,3,8,9],
                   'C' : ['a','b','c','d','e']})

df
# Out:
#    A  B  C
# 0  1  3  a
# 1  1  6  b
# 2  2  3  c
# 3  3  8  d
# 4  4  9  e

# %%
#otra forma de reemplazar valores es mediante el metodo replace
df.replace(1,100)
# Out:
#      A  B  C
# 0  100  3  a
# 1  100  6  b
# 2    2  3  c
# 3    3  8  d
# 4    4  9  e

# %%
#tambien podemos cambiar valores mediante listas
df.replace([1,3],[100,300])
# Out:
#      A    B  C
# 0  100  300  a
# 1  100    6  b
# 2    2  300  c
# 3  300    8  d
# 4    4    9  e

# %%
df = pd.read_csv('log.csv')
df.head(10)
# Out:
#          time    user       video  playback position paused  volume
# 0  1469974424  cheryl  intro.html                  5  False    10.0
# 1  1469974454  cheryl  intro.html                  6    NaN     NaN
# 2  1469974544  cheryl  intro.html                  9    NaN     NaN
# 3  1469974574  cheryl  intro.html                 10    NaN     NaN
# 4  1469977514     bob  intro.html                  1    NaN     NaN
# 5  1469977544     bob  intro.html                  1    NaN     NaN
# 6  1469977574     bob  intro.html                  1    NaN     NaN
# 7  1469977604     bob  intro.html                  1    NaN     NaN
# 8  1469974604  cheryl  intro.html                 11    NaN     NaN
# 9  1469974694  cheryl  intro.html                 14    NaN     NaN

# %%
#en este caso capturamos valores en las columnas que cumplan con nuestro patron que establecemos con ayuda de regex
df.replace(to_replace='[\w]+\.html', value="webpage", regex=True, inplace=True)

# %%
df['video'].unique()
# Out:
# array(['webpage'], dtype=object)

# %%
#finalmente tenemos que considerar que cuando calculamos estadisticos respecto a las columnas estos ignoran los valores faltantes
